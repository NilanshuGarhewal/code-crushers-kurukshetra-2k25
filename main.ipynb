# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import warnings
from scipy.stats import randint, uniform
import random
from sklearn.model_selection import KFold, cross_val_score
import re
import tldextract
from urllib.parse import urlparse
from collections import Counter
from scipy.stats import entropy
warnings.filterwarnings("ignore")

# %%
X = pd.read_csv('phishing_site_urls.csv')

X['URL'].str.strip()  # Remove unnecessary whitespaces

X
# Out:
#                                                       URL Label
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3       mail.printakid.com/www.online.americanexpress....   bad
# 4       thewhiskeydregs.com/wp-content/themes/widescre...   bad
# ...                                                   ...   ...
# 549341                                    23.227.196.215/   bad
# 549342                                 apple-checker.org/   bad
# 549343                                  apple-iclods.org/   bad
# 549344                                 apple-uptoday.org/   bad
# 549345                                  apple-search.info   bad
#
# [549346 rows x 2 columns]

# %%
special_df = pd.DataFrame()

special_chars = set() 

def find_special_char(x):
    special_chars_in_x = re.findall(r'[^a-zA-Z0-9]', x)
    special_chars.update(special_chars_in_x)
    return None

X_bad = X[X['Label'] == 'bad']
X_bad['URL'].apply(find_special_char)

special_chars = list(special_chars)

special_chars.remove('.')
special_chars.remove('/')

special_df['Special Character'] = special_chars
special_df['Frequency in bad URLs'] = special_df['Special Character'].apply(lambda x: X_bad[X_bad['URL'].str.contains(re.escape(x), regex=True)].shape[0])
special_df['Bad probability'] = special_df['Frequency in bad URLs']/special_df['Special Character'].apply(lambda x: X[X['URL'].str.contains(re.escape(x), regex=True)].shape[0])
special_df['Score'] = special_df['Bad probability']*special_df['Frequency in bad URLs'].apply(math.log)

special_df.sort_values(by='Score', ignore_index=True, ascending=False, inplace=True)
special_df
# Out:
#     Special Character  Frequency in bad URLs  Bad probability     Score
# 0                   \                   6363         0.966874  8.468132
# 1                   ;                  11294         0.906639  8.460778
# 2                                       1066         0.955197  6.659318
# 3                   @                   1809         0.882870  6.621990
# 4                   '                   3591         0.774089  6.336839
# ..                ...                    ...              ...       ...
# 167                                       1         0.041667  0.000000
# 168                 ö                      1         0.037037  0.000000
# 169                                       1         0.032258  0.000000
# 170                 É                      1         0.031250  0.000000
# 171                                       1         0.041667  0.000000
#
# [172 rows x 4 columns]

# %%
dangerous_chars = list(special_df['Special Character'].head(10))
print(dangerous_chars)
plt.bar(special_df['Special Character'].head(10), special_df['Score'].head(10), color = 'green')
plt.xlabel('Special Character')
plt.ylabel('Score')
plt.show()
# Out:
# ['\\', ';', ' ', '@', "'", ':', '&', '>', '<', '=']

# %%
TLD_df = pd.DataFrame()

TLD_list = pd.Series(X_bad['URL'].apply(lambda x: tldextract.extract(x).suffix)).unique()

TLD_df['TLD'] = TLD_list

TLD_df['Frequency in bad URLs'] = TLD_df['TLD'].apply(lambda x: X_bad[X_bad['URL'].str.contains(re.escape(x), regex=True)].shape[0])
TLD_df['Bad probability'] = TLD_df['Frequency in bad URLs']/TLD_df['TLD'].apply(lambda x: X[X['URL'].str.contains(re.escape(x), regex=True)].shape[0])
TLD_df['Score'] = TLD_df['Bad probability']*TLD_df['Frequency in bad URLs'].apply(math.log)

TLD_df.sort_values(by='Score', ignore_index=True, ascending=False, inplace=True)
TLD_df
# Out:
#            TLD  Frequency in bad URLs  Bad probability     Score
# 0       com.br                   4235         0.982599  8.205817
# 1           mx                   3698         0.931486  7.652669
# 2           cm                  10508         0.812495  7.523618
# 3           bf                   3900         0.878576  7.264711
# 4         date                   5402         0.775258  6.662977
# ..         ...                    ...              ...       ...
# 601     com.bb                      1         1.000000  0.000000
# 602  sa.edu.au                      1         0.142857  0.000000
# 603     gob.do                      1         1.000000  0.000000
# 604     edu.bt                      1         1.000000  0.000000
# 605    info.ro                      1         1.000000  0.000000
#
# [606 rows x 4 columns]

# %%
dangerous_TLDs = list(TLD_df['TLD'].head(10))
print(dangerous_TLDs)
plt.bar(TLD_df['TLD'].head(10), TLD_df['Score'].head(10), color = 'green')
plt.xlabel('Dangerous TLD')
plt.ylabel('Score')
plt.show()
# Out:
# ['com.br', 'mx', 'cm', 'bf', 'date', 'run', 'xyz', 'mg', 'com.ar', 'ph']

# %%
X['URL length'] = X['URL'].apply(len)

#2 Numbers of dots

X['Number of dots'] = X['URL'].apply(lambda x: x.count('.'))

#3 Number of slashes

X['Number of slashes'] = X['URL'].apply(lambda x: x.count('/'))

#4 Percentage of numerical characters

X['Percentage of numerical characters'] = X['URL'].apply(lambda x: sum(c.isdigit() for c in x))/X['URL length']

#5 Dangerous characters

X['Dangerous characters'] = X['URL'].apply(lambda x: any(char in x for char in dangerous_chars))

#6 Dangerous TLD

X['Dangerous TLD'] = X['URL'].apply(lambda x: tldextract.extract(x).suffix in dangerous_TLDs)

#7 Entropy

def urlentropy(url):
    frequencies = Counter(url)
    prob = [frequencies[char] / len(url) for char in url]
    return entropy(prob, base=2)


X['Entropy'] = X['URL'].apply(urlentropy)

#8 IP Address

ip_pattern = r'[0-9]+(?:\.[0-9]+){3}'
X['IP Address'] = X['URL'].apply(lambda x: bool(re.search(ip_pattern, x)))

#9 Domain name length

X['Domain name length'] = X['URL'].apply(lambda x: len(tldextract.extract(x).domain))

#10 Suspicious keywords

sus_words = ['secure', 'account', 'update', 'login', 'verify' ,'signin', 'bank',
            'notify', 'click', 'inconvenient']

X['Suspicious keywords'] = X['URL'].apply(lambda x: sum([word in x for word in sus_words]) != 0)


#11 Repetitions

X['Repetitions'] = X['URL'].apply(lambda x: True if re.search(r'(.)\1{2,}', tldextract.extract(x).domain) else False)

#12 Redirections

def redirection(url):
  pos = url.rfind('//') #If the // is not found, it returns -1
  return pos>7

X['Redirections'] = X['URL'].apply(redirection)

#We print the new dataset

X
# Out:
#                                                       URL Label  URL length  \
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad         225
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad          81
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad         177
# 3       mail.printakid.com/www.online.americanexpress....   bad          60
# 4       thewhiskeydregs.com/wp-content/themes/widescre...   bad         116
# ...                                                   ...   ...         ...
# 549341                                    23.227.196.215/   bad          15
# 549342                                 apple-checker.org/   bad          18
# 549343                                  apple-iclods.org/   bad          17
# 549344                                 apple-uptoday.org/   bad          18
# 549345                                  apple-search.info   bad          17
#
#         Number of dots  Number of slashes  Percentage of numerical characters  \
# 0                    6                 10                            0.257778
# 1                    5                  4                            0.012346
# 2                    7                 11                            0.265537
# 3                    6                  2                            0.000000
# 4                    1                 10                            0.181034
# ...                ...                ...                                 ...
# 549341               3                  1                            0.733333
# 549342               1                  1                            0.000000
# 549343               1                  1                            0.000000
# 549344               1                  1                            0.000000
# 549345               1                  0                            0.000000
#
#         Dangerous characters  Dangerous TLD   Entropy  IP Address  \
# 0                       True          False  7.667575       False
# 1                       True          False  6.190289       False
# 2                      False          False  7.288285       False
# 3                      False          False  5.786667       False
# 4                      False          False  6.611978       False
# ...                      ...            ...       ...         ...
# 549341                 False          False  3.693150        True
# 549342                 False          False  4.031402       False
# 549343                 False          False  4.001823       False
# 549344                 False          False  4.012188       False
# 549345                 False          False  4.001823       False
#
#         Domain name length  Suspicious keywords  Repetitions  Redirections
# 0                        6                 True        False         False
# 1                        7                False        False         False
# 2                       12                 True        False         False
# 3                        9                False        False         False
# 4                       15                False        False          True
# ...                    ...                  ...          ...           ...
# 549341                  14                False        False         False
# 549342                  13                False        False         False
# 549343                  12                False        False         False
# 549344                  13                False        False         False
# 549345                  12                False        False         False
#
# [549346 rows x 14 columns]

# %%
scaler = StandardScaler()

num_columns = ['URL length', 'Number of dots', 'Number of slashes', 'Domain name length', 'Entropy']

X[num_columns] = scaler.fit_transform(X[num_columns])

# %%
X['IP Address'] = X['IP Address'].astype(int)
X['Suspicious keywords'] = X['Suspicious keywords'].astype(int)
X['Repetitions'] = X['Repetitions'].astype(int)
X['Redirections'] = X['Redirections'].astype(int)
X['Dangerous characters'] = X['Dangerous characters'].astype(int)
X['Dangerous TLD'] = X['Dangerous TLD'].astype(int)
X['Label'] = (X['Label'] == 'good').astype(int)

X.drop(columns=['URL'], inplace=True)

X
# Out:
#         Label  URL length  Number of dots  Number of slashes  \
# 0           0    3.923264        2.599770           4.734477
# 1           0    0.681338        1.939541           0.974386
# 2           0    2.842622        3.259998           5.361159
# 3           0    0.208557        2.599770          -0.278978
# 4           0    1.469306       -0.701371           4.734477
# ...       ...         ...             ...                ...
# 549341      0   -0.804544        0.619085          -0.905660
# 549342      0   -0.737004       -0.701371          -0.905660
# 549343      0   -0.759518       -0.701371          -0.905660
# 549344      0   -0.737004       -0.701371          -0.905660
# 549345      0   -0.759518       -0.701371          -1.532342
#
#         Percentage of numerical characters  Dangerous characters  \
# 0                                 0.257778                     1
# 1                                 0.012346                     1
# 2                                 0.265537                     0
# 3                                 0.000000                     0
# 4                                 0.181034                     0
# ...                                    ...                   ...
# 549341                            0.733333                     0
# 549342                            0.000000                     0
# 549343                            0.000000                     0
# 549344                            0.000000                     0
# 549345                            0.000000                     0
#
#         Dangerous TLD   Entropy  IP Address  Domain name length  \
# 0                   0  3.043151           0           -0.799144
# 1                   0  1.213456           0           -0.582606
# 2                   0  2.573382           0            0.500081
# 3                   0  0.713550           0           -0.149531
# 4                   0  1.735740           0            1.149694
# ...               ...       ...         ...                 ...
# 549341              0 -1.879379           1            0.933156
# 549342              0 -1.460437           0            0.716619
# 549343              0 -1.497072           0            0.500081
# 549344              0 -1.484234           0            0.716619
# 549345              0 -1.497072           0            0.500081
#
#         Suspicious keywords  Repetitions  Redirections
# 0                         1            0             0
# 1                         0            0             0
# 2                         1            0             0
# 3                         0            0             0
# 4                         0            0             1
# ...                     ...          ...           ...
# 549341                    0            0             0
# 549342                    0            0             0
# 549343                    0            0             0
# 549344                    0            0             0
# 549345                    0            0             0
#
# [549346 rows x 13 columns]

# %%
corr_matrix = X.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, annot_kws={"size": 6})
plt.show()
sns.heatmap(corr_matrix[['Label']].sort_values(by='Label').T, annot=True, cmap='coolwarm', linewidths=0.5, annot_kws={"size": 8})
plt.show()
print(corr_matrix[['Label']].sort_values(by='Label'))
# Out:
#                                        Label
# Suspicious keywords                -0.360325
# Number of dots                     -0.293474
# Percentage of numerical characters -0.204039
# IP Address                         -0.191832
# URL length                         -0.177295
# Dangerous TLD                      -0.163621
# Dangerous characters               -0.146440
# Domain name length                 -0.144381
# Number of slashes                  -0.118405
# Entropy                            -0.096089
# Redirections                       -0.088167
# Repetitions                        -0.049215
# Label                               1.000000

# %%
pca = PCA(n_components=1)
X['Entropy and length (PCA)'] = pca.fit_transform(X[['Entropy', 'URL length']])
X.drop(columns=['Entropy', 'URL length'], inplace=True)

X
# Out:
#         Label  Number of dots  Number of slashes  \
# 0           0        2.599770           4.734477
# 1           0        1.939541           0.974386
# 2           0        3.259998           5.361159
# 3           0        2.599770          -0.278978
# 4           0       -0.701371           4.734477
# ...       ...             ...                ...
# 549341      0        0.619085          -0.905660
# 549342      0       -0.701371          -0.905660
# 549343      0       -0.701371          -0.905660
# 549344      0       -0.701371          -0.905660
# 549345      0       -0.701371          -1.532342
#
#         Percentage of numerical characters  Dangerous characters  \
# 0                                 0.257778                     1
# 1                                 0.012346                     1
# 2                                 0.265537                     0
# 3                                 0.000000                     0
# 4                                 0.181034                     0
# ...                                    ...                   ...
# 549341                            0.733333                     0
# 549342                            0.000000                     0
# 549343                            0.000000                     0
# 549344                            0.000000                     0
# 549345                            0.000000                     0
#
#         Dangerous TLD  IP Address  Domain name length  Suspicious keywords  \
# 0                   0           0           -0.799144                    1
# 1                   0           0           -0.582606                    0
# 2                   0           0            0.500081                    1
# 3                   0           0           -0.149531                    0
# 4                   0           0            1.149694                    0
# ...               ...         ...                 ...                  ...
# 549341              0           1            0.933156                    0
# 549342              0           0            0.716619                    0
# 549343              0           0            0.500081                    0
# 549344              0           0            0.716619                    0
# 549345              0           0            0.500081                    0
#
#         Repetitions  Redirections  Entropy and length (PCA)
# 0                 0             0                  4.926000
# 1                 0             0                  1.339822
# 2                 0             0                  3.829693
# 3                 0             0                  0.652028
# 4                 0             1                  2.266310
# ...             ...           ...                       ...
# 549341            0             0                 -1.897821
# 549342            0             0                 -1.553825
# 549343            0             0                 -1.595650
# 549344            0             0                 -1.570652
# 549345            0             0                 -1.595650
#
# [549346 rows x 12 columns]

# %% [markdown]
# Train - Test Data

# %%
X['Label'].value_counts(normalize=True)
# Out:
# Label
# 1    0.715258
# 0    0.284742
# Name: proportion, dtype: float64

# %%
n_samples = X['Label'].value_counts()[0]
X_good = X[X['Label'] == 1]
X_bad = X[X['Label'] == 0]
X_goodsample = X_good.sample(n=n_samples, random_state=22)
X_goodmissing = X_good.drop(X_goodsample.index)

X = pd.concat([X_bad, X_goodsample], ignore_index=True)

X
# Out:
#         Label  Number of dots  Number of slashes  \
# 0           0        2.599770           4.734477
# 1           0        1.939541           0.974386
# 2           0        3.259998           5.361159
# 3           0        2.599770          -0.278978
# 4           0       -0.701371           4.734477
# ...       ...             ...                ...
# 312839      1       -0.701371          -0.905660
# 312840      1       -0.041143          -0.278978
# 312841      1       -0.041143           0.347704
# 312842      1       -0.041143          -0.905660
# 312843      1       -0.701371           0.974386
#
#         Percentage of numerical characters  Dangerous characters  \
# 0                                 0.257778                     1
# 1                                 0.012346                     1
# 2                                 0.265537                     0
# 3                                 0.000000                     0
# 4                                 0.181034                     0
# ...                                    ...                   ...
# 312839                            0.000000                     0
# 312840                            0.000000                     0
# 312841                            0.000000                     0
# 312842                            0.000000                     0
# 312843                            0.000000                     0
#
#         Dangerous TLD  IP Address  Domain name length  Suspicious keywords  \
# 0                   0           0           -0.799144                    1
# 1                   0           0           -0.582606                    0
# 2                   0           0            0.500081                    1
# 3                   0           0           -0.149531                    0
# 4                   0           0            1.149694                    0
# ...               ...         ...                 ...                  ...
# 312839              0           0           -0.582606                    0
# 312840              0           0           -0.149531                    0
# 312841              0           0           -1.448756                    0
# 312842              0           0           -0.366069                    0
# 312843              0           0           -0.366069                    0
#
#         Repetitions  Redirections  Entropy and length (PCA)
# 0                 0             0                  4.926000
# 1                 0             0                  1.339822
# 2                 0             0                  3.829693
# 3                 0             0                  0.652028
# 4                 0             1                  2.266310
# ...             ...           ...                       ...
# 312839            0             0                 -0.692077
# 312840            0             0                 -0.964574
# 312841            0             0                 -0.415293
# 312842            0             0                 -0.232647
# 312843            0             0                 -0.794006
#
# [312844 rows x 12 columns]

# %%
y = X['Label']
X.drop(columns=['Label'], inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=22)

y_goodmissing = X_goodmissing['Label']
X_goodmissing.drop(columns=['Label'], inplace=True)

# Merging X_test and X_goodmissing

X_test = pd.concat([X_test, X_goodmissing], axis=0)

# Merging y_test and y_goodmissing

y_test = pd.concat([y_test, y_goodmissing], axis=0)

# %% [markdown]
# Construction of an ML Mdoel

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=22)

xgb_model = XGBClassifier(random_state=22)
print(cross_val_score(xgb_model, X_train, y_train, cv=kf, scoring='accuracy').mean())

rf_model = RandomForestClassifier(random_state=22)
print(cross_val_score(rf_model, X_train, y_train, cv=kf, scoring='accuracy').mean())
# Out:
# 0.8395924483068624
# 0.8601937868344821

# %%
rf_model.fit(X_train, y_train)
importances = rf_model.feature_importances_
feature_names = X.columns 
indices = np.argsort(importances)[::-1]

plt.title('Feature Importance (RandomForestClassifier)')
plt.bar(range(X.shape[1]), importances[indices], align='center')
plt.xticks(range(X.shape[1]), feature_names[indices], rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.show()

# %%
xgb_model.fit(X_train, y_train)
importances = xgb_model.feature_importances_
feature_names = X.columns 
indices = np.argsort(importances)[::-1]

plt.title('Feature Importance (XGBClassifier)')
plt.bar(range(X.shape[1]), importances[indices], align='center')
plt.xticks(range(X.shape[1]), feature_names[indices], rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.show()

# %%
from sklearn.metrics import accuracy_score

rf_pred = rf_model.predict(X_test)
xgb_pred = xgb_model.predict(X_test)

print(accuracy_score(y_test, rf_pred))
print(accuracy_score(y_test, xgb_pred))
# Out:
# 0.8642262205295732
# 0.8631896773675816

# %% [markdown]
# Hyperparatemer Tuning

# %%
import optuna



def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 400)
    max_depth = trial.suggest_int('max_depth', 3, 7)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 0.3)
    subsample = trial.suggest_uniform('subsample', 0.6, 1.0)
    reg_alpha = trial.suggest_loguniform('reg_alpha', 1e-3, 10.0)

    
    model = XGBClassifier(
        random_state=22,
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        reg_alpha=reg_alpha,
        use_label_encoder=False,
        eval_metric='mlogloss'
    )

    
    mean_score = cross_val_score(model, X, y, cv=kf, scoring='accuracy').mean()
    return mean_score 


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50) 


print("Best hyperparameters:", study.best_params)
print("Best accuracy:", study.best_value)

best_xgb_model =XGBClassifier(random_state=22, **study.best_params)
# Out:
# [I 2025-03-26 17:48:37,956] A new study created in memory with name: no-name-2a1c43dd-cc5d-4f27-a051-a38f06121299
# [I 2025-03-26 17:48:47,525] Trial 0 finished with value: 0.7438659492278656 and parameters: {'n_estimators': 311, 'max_depth': 5, 'learning_rate': 0.0017015245149808835, 'subsample': 0.9125387149074108, 'reg_alpha': 0.04082408286953865}. Best is trial 0 with value: 0.7438659492278656.
# [I 2025-03-26 17:48:49,831] Trial 1 finished with value: 0.8243533534002049 and parameters: {'n_estimators': 114, 'max_depth': 4, 'learning_rate': 0.24597095347620035, 'subsample': 0.9829893776149563, 'reg_alpha': 0.002783522563865758}. Best is trial 1 with value: 0.8243533534002049.
# [I 2025-03-26 17:48:54,627] Trial 2 finished with value: 0.7722538966561615 and parameters: {'n_estimators': 263, 'max_depth': 5, 'learning_rate': 0.009234547264870392, 'subsample': 0.7178966576490144, 'reg_alpha': 0.004261569690674292}. Best is trial 1 with value: 0.8243533534002049.
# [I 2025-03-26 17:48:58,950] Trial 3 finished with value: 0.7824794413995879 and parameters: {'n_estimators': 196, 'max_depth': 6, 'learning_rate': 0.011577140880386149, 'subsample': 0.784248006284457, 'reg_alpha': 0.29593349623094867}. Best is trial 1 with value: 0.8243533534002049.
# [I 2025-03-26 17:49:04,081] Trial 4 finished with value: 0.8329327065378389 and parameters: {'n_estimators': 199, 'max_depth': 7, 'learning_rate': 0.04910767121764908, 'subsample': 0.7887872164576646, 'reg_alpha': 0.8920293450193724}. Best is trial 4 with value: 0.8329327065378389.
# [I 2025-03-26 17:49:08,010] Trial 5 finished with value: 0.8401631468396967 and parameters: {'n_estimators': 176, 'max_depth': 5, 'learning_rate': 0.2808493742627954, 'subsample': 0.9608791621573648, 'reg_alpha': 6.667886340027372}. Best is trial 5 with value: 0.8401631468396967.
# [I 2025-03-26 17:49:10,371] Trial 6 finished with value: 0.714097126653937 and parameters: {'n_estimators': 102, 'max_depth': 4, 'learning_rate': 0.002144515070567418, 'subsample': 0.6601919413444094, 'reg_alpha': 0.09631183332308811}. Best is trial 5 with value: 0.8401631468396967.
# [I 2025-03-26 17:52:01,322] Trial 29 finished with value: 0.8479242008428312 and parameters: {'n_estimators': 364, 'max_depth': 6, 'learning_rate': 0.18653303896490755, 'subsample': 0.9381316240513328, 'reg_alpha': 0.035433675552998964}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:52:09,756] Trial 30 finished with value: 0.7369008180602482 and parameters: {'n_estimators': 364, 'max_depth': 5, 'learning_rate': 0.0011094844530204259, 'subsample': 0.8905919857138813, 'reg_alpha': 0.01230369267971671}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:52:19,091] Trial 31 finished with value: 0.8475534103387424 and parameters: {'n_estimators': 370, 'max_depth': 6, 'learning_rate': 0.17106248178808908, 'subsample': 0.9429149239330341, 'reg_alpha': 0.038143243863979555}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:52:28,529] Trial 32 finished with value: 0.8504813846879191 and parameters: {'n_estimators': 332, 'max_depth': 6, 'learning_rate': 0.29632641731895715, 'subsample': 0.9338114147376733, 'reg_alpha': 0.13532918641249947}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:52:35,792] Trial 33 finished with value: 0.8443313595656848 and parameters: {'n_estimators': 324, 'max_depth': 5, 'learning_rate': 0.27051766282339096, 'subsample': 0.9762281134107859, 'reg_alpha': 0.1458761552517798}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:52:44,342] Trial 34 finished with value: 0.8508681580481433 and parameters: {'n_estimators': 342, 'max_depth': 6, 'learning_rate': 0.29524714614562214, 'subsample': 0.9275090515924246, 'reg_alpha': 0.12752451979168083}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:52:53,613] Trial 35 finished with value: 0.8503567253191094 and parameters: {'n_estimators': 341, 'max_depth': 6, 'learning_rate': 0.2633160495625263, 'subsample': 0.920563443021273, 'reg_alpha': 0.49492728495531446}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:53:00,899] Trial 36 finished with value: 0.8449291001715054 and parameters: {'n_estimators': 310, 'max_depth': 5, 'learning_rate': 0.2953572740166372, 'subsample': 0.87495262670865, 'reg_alpha': 0.5216805520312255}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:53:07,357] Trial 37 finished with value: 0.8295604149614867 and parameters: {'n_estimators': 343, 'max_depth': 3, 'learning_rate': 0.289180165030317, 'subsample': 0.9205297464180074, 'reg_alpha': 0.5110590806713748}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:53:14,388] Trial 38 finished with value: 0.8187019728952142 and parameters: {'n_estimators': 341, 'max_depth': 4, 'learning_rate': 0.0583534089756692, 'subsample': 0.9768363080155967, 'reg_alpha': 2.6267789549108533}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:53:22,779] Trial 39 finished with value: 0.7963234085174692 and parameters: {'n_estimators': 317, 'max_depth': 6, 'learning_rate': 0.011156012288090126, 'subsample': 0.9016467667165498, 'reg_alpha': 0.05778868755110778}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:53:32,279] Trial 40 finished with value: 0.7596821363247718 and parameters: {'n_estimators': 308, 'max_depth': 5, 'learning_rate': 0.0033941842781077688, 'subsample': 0.8736526494774879, 'reg_alpha': 0.004663911922723563}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:53:45,134] Trial 41 finished with value: 0.8497557838997726 and parameters: {'n_estimators': 384, 'max_depth': 6, 'learning_rate': 0.2116973587034168, 'subsample': 0.9240900425486478, 'reg_alpha': 0.11590377136690488}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:54:01,742] Trial 42 finished with value: 0.8502927926071678 and parameters: {'n_estimators': 383, 'max_depth': 6, 'learning_rate': 0.23281762403988024, 'subsample': 0.9280208271700232, 'reg_alpha': 0.4101553019917668}. Best is trial 25 with value: 0.8528787480025768.
# [I 2025-03-26 17:54:13,932] Trial 43 finished with value: 0.8536810617980984 and parameters: {'n_estimators': 335, 'max_depth': 7, 'learning_rate': 0.2392764144869922, 'subsample': 0.966796657912061, 'reg_alpha': 0.7030497627269714}. Best is trial 43 with value: 0.8536810617980984.
# [I 2025-03-26 17:54:23,541] Trial 44 finished with value: 0.849295490284114 and parameters: {'n_estimators': 337, 'max_depth': 7, 'learning_rate': 0.1290762737503723, 'subsample': 0.9675227427245381, 'reg_alpha': 0.18177951093769745}. Best is trial 43 with value: 0.8536810617980984.
# [I 2025-03-26 17:54:33,353] Trial 45 finished with value: 0.84520719193076 and parameters: {'n_estimators': 354, 'max_depth': 7, 'learning_rate': 0.0846979153859695, 'subsample': 0.9968463818954006, 'reg_alpha': 1.4629270524474225}. Best is trial 43 with value: 0.8536810617980984.
# [I 2025-03-26 17:54:43,601] Trial 46 finished with value: 0.8535276309402725 and parameters: {'n_estimators': 326, 'max_depth': 7, 'learning_rate': 0.23484559305444622, 'subsample': 0.8967991011226166, 'reg_alpha': 0.9197540677233361}. Best is trial 43 with value: 0.8536810617980984.
# [I 2025-03-26 17:54:52,412] Trial 47 finished with value: 0.8523992744568568 and parameters: {'n_estimators': 301, 'max_depth': 7, 'learning_rate': 0.2188834801534865, 'subsample': 0.8967828368599612, 'reg_alpha': 0.7749731396001384}. Best is trial 43 with value: 0.8536810617980984.
# [I 2025-03-26 17:55:01,073] Trial 48 finished with value: 0.8403677196309168 and parameters: {'n_estimators': 301, 'max_depth': 7, 'learning_rate': 0.059275169954366276, 'subsample': 0.8925638334376969, 'reg_alpha': 0.7498605729357096}. Best is trial 43 with value: 0.8536810617980984.
# [I 2025-03-26 17:55:13,060] Trial 49 finished with value: 0.8481415609182271 and parameters: {'n_estimators': 324, 'max_depth': 7, 'learning_rate': 0.11728807004525818, 'subsample': 0.872242693927652, 'reg_alpha': 4.251953185197253}. Best is trial 43 with value: 0.8536810617980984.
# Best hyperparameters: {'n_estimators': 335, 'max_depth': 7, 'learning_rate': 0.2392764144869922, 'subsample': 0.966796657912061, 'reg_alpha': 0.7030497627269714}
# Best accuracy: 0.8536810617980984

# %%
best_xgb_model.fit(X_train, y_train)

best_xgb_pred = best_xgb_model.predict(X_test)

print(accuracy_score(y_test, best_xgb_pred))
# Out:
# 0.8729064335893484
